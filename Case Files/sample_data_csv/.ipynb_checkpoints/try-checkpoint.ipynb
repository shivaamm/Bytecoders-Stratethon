# %%
## https://github.com/synthetichealth/synthea/wiki/CSV-File-Data-Dictionary

import pandas as pd

# %%
patients = pd.read_csv('patients.csv')
patients.isnull().sum()
# Out:
# Id                        0
# BIRTHDATE                 0
# DEATHDATE              1000
# SSN                       0
# DRIVERS                 213
# PASSPORT                273
# PREFIX                  244
# FIRST                     0
# LAST                      0
# SUFFIX                 1159
# MAIDEN                  840
# MARITAL                 380
# RACE                      0
# ETHNICITY                 0
# GENDER                    0
# BIRTHPLACE                0
# ADDRESS                   0
# CITY                      0
# STATE                     0
# COUNTY                    0
# ZIP                     543
# LAT                       0
# LON                       0
# HEALTHCARE_EXPENSES       0
# HEALTHCARE_COVERAGE       0
# dtype: int64

# %%
allergies = pd.read_csv('allergies.csv')
allergies.isnull().sum()
#allergies.shape
allergies.head()
# Out:
#         START STOP                               PATIENT  \
# 0  25-10-1982  NaN  76982e06-f8b8-4509-9ca3-65a99c8650fe
# 1  25-10-1982  NaN  76982e06-f8b8-4509-9ca3-65a99c8650fe
# 2  25-01-2002  NaN  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# 3  25-01-2002  NaN  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# 4  25-01-2002  NaN  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
#
#                               ENCOUNTER       CODE              DESCRIPTION
# 0  b896bf40-8b72-42b7-b205-142ee3a56b55  300916003            Latex allergy
# 1  b896bf40-8b72-42b7-b205-142ee3a56b55  300913006        Shellfish allergy
# 2  7be1a590-4239-4826-9872-031327f3c368  419474003         Allergy to mould
# 3  7be1a590-4239-4826-9872-031327f3c368  232347008  Dander (animal) allergy
# 4  7be1a590-4239-4826-9872-031327f3c368  418689008  Allergy to grass pollen

# %%
medications = pd.read_csv('medications.csv')
medications.isnull().sum()
#medications.shape
# Out:
# START                    0
# STOP                  1895
# PATIENT                  0
# PAYER                    0
# ENCOUNTER                0
# CODE                     0
# DESCRIPTION              0
# BASE_COST                0
# PAYER_COVERAGE           0
# DISPENSES                0
# TOTALCOST                0
# REASONCODE           11117
# REASONDESCRIPTION    11117
# dtype: int64

# %%
procedures = pd.read_csv('procedures.csv')
procedures.head()
procedures.isnull().sum()

# %%
conditions = pd.read_csv('conditions.csv')
conditions['PATIENT']

# %%
conditions.head()

# %%
encounter = pd.read_csv('encounters.csv')
encounter.head()

# %%
patients.shape

# %%
1171-1152

# %%
df2 = conditions[conditions['STOP'].isnull()]
df2.head()

# %%
df2.shape

# %%
df2['PATIENT'].nunique()

# %%
1171 - 922

# %%
df3 = conditions[conditions['STOP'].notnull()]
df3.head()

# %%
df3['PATIENT'].nunique()

# %%
1119+922

# %%
allergies.isnull().sum()

# %%
allergies.shape

# %%
597 - 533

# %% [markdown]
# From allergies

# %%
import pandas as pd
conditions = pd.read_csv('allergies.csv')

# %%
total_patients_conditions = conditions['PATIENT'].nunique()
total_patients_non_adherant = conditions[conditions['STOP'].isnull()]['PATIENT'].nunique()
print('Total unique patients in conditions.csv : ',total_patients_conditions)
print('Total unique patients whose condition was not resolved (non - adherent patients) : ',total_patients_non_adherant)
print('Total unique patients whose condition was resolved (adherent patients) : ',total_patients_conditions-total_patients_non_adherant)

# %%
conditions['isadherent'] = conditions['STOP'].notnull()*1
conditions.head()

# %%
# Extracting patients and isadherent columns seperately
patients_info = conditions[['PATIENT', 'isadherent']]
patients_info.head()

# %%
#removing duplicates
patients_info = patients_info.drop_duplicates()
patients_info.shape

# %%
print('But total unique patients in conditions.csv : ',total_patients_conditions)

# %%
group = patients_info.groupby('PATIENT')
patients_info = group.apply(lambda x : x['isadherent'].unique())
patients_info = patients_info.reset_index() 
patients_info.rename(columns = {0:'isadherent'}, inplace = True)

# %%
patients_info.head()

# %%
patients_info1 = group.apply(lambda x : x['isadherent'].nunique())
patients_info1 = patients_info1.reset_index() 
patients_info1.rename(columns = {0:'freq_isadherent'}, inplace = True)
freq_isadherent = patients_info1['freq_isadherent']
patients_info = pd.concat([patients_info, freq_isadherent], axis=1)
patients_info.head()

# %%
patients_info.loc[patients_info['freq_isadherent'] > 1, 'isadherent'] = 0
patients_info.drop('freq_isadherent',axis = 1,inplace = True)
print(patients_info['isadherent'].value_counts())

# %%
# converting [0] -> 0 and [1] -> 1
patients_info.loc[patients_info['isadherent'] == 0, 'isadherent'] = 0
patients_info.loc[patients_info['isadherent'] == 1, 'isadherent'] = 1
patients_info['isadherent'].value_counts()

# %%
patients_info

# %%
patients = pd.read_csv('patients.csv')
print('Total shape : ',patients.shape)
patients.info()

# %%
# Droping unnecessary columns
patients.drop(['DEATHDATE','DRIVERS','PASSPORT','PREFIX','SUFFIX','MAIDEN','MARITAL','COUNTY','ZIP','LAT','LON'],axis = 1,inplace = True)
patients.head()

# %%
patients_info.rename(columns = {'PATIENT':'Id'}, inplace = True)
patients_info.head()

# %%
df = (pd.merge(patients, patients_info,how='outer',on = 'Id'))
df.head()

# %%
df.isnull().sum()

# %%
df.shape

# %%
1171 - 1030

# %% [markdown]
# # medications

# %%
import dateutil.parser

# %%
# medications.shape

# %%
# patients['Id'].nunique()

# %%
# medications['PATIENT'].nunique()

# %%
# 1171 - 1107

# %%
medications.head(2)
# Out:
#                   START                  STOP  \
# 0  2010-05-05T00:26:23Z  2011-04-30T00:26:23Z
# 1  2011-04-30T00:26:23Z  2012-04-24T00:26:23Z
#
#                                 PATIENT                                 PAYER  \
# 0  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#                               ENCOUNTER    CODE  \
# 0  1e0d6b0e-1711-4a25-99f9-b1c700c9b260  389221
# 1  6aa37300-d1b4-48e7-a2f8-5e0f70f48f38  389221
#
#                        DESCRIPTION  BASE_COST  PAYER_COVERAGE  DISPENSES  \
# 0  Etonogestrel 68 MG Drug Implant     677.08             0.0         12
# 1  Etonogestrel 68 MG Drug Implant     624.09             0.0         12
#
#    TOTALCOST  REASONCODE REASONDESCRIPTION
# 0    8124.96         NaN               NaN
# 1    7489.08         NaN               NaN

# %%
def apSTART(row):
    if pd.isna(row['START']) :
        return None
    else :
        return dateutil.parser.parse(row['START'])

# %%
def apSTOP(row):
    if pd.isna(row['STOP']) :
        return None
    else :
        return dateutil.parser.parse(row['STOP'])

# %%
medications['START'] = medications.apply(lambda row:apSTART(row) , axis=1)
medications['STOP'] = medications.apply(lambda row: apSTOP(row), axis=1)
medications.head(2)
# Out:
#                       START                      STOP  \
# 0 2010-05-05 00:26:23+00:00 2011-04-30 00:26:23+00:00
# 1 2011-04-30 00:26:23+00:00 2012-04-24 00:26:23+00:00
#
#                                 PATIENT                                 PAYER  \
# 0  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#                               ENCOUNTER    CODE  \
# 0  1e0d6b0e-1711-4a25-99f9-b1c700c9b260  389221
# 1  6aa37300-d1b4-48e7-a2f8-5e0f70f48f38  389221
#
#                        DESCRIPTION  BASE_COST  PAYER_COVERAGE  DISPENSES  \
# 0  Etonogestrel 68 MG Drug Implant     677.08             0.0         12
# 1  Etonogestrel 68 MG Drug Implant     624.09             0.0         12
#
#    TOTALCOST  REASONCODE REASONDESCRIPTION
# 0    8124.96         NaN               NaN
# 1    7489.08         NaN               NaN

# %%
def ap(row):
    if pd.isna(row['STOP']) :
        return None
    else :
        return (row['STOP']-row['START'])

# %%
medications['stop-start'] = medications.apply(lambda row: ap(row), axis=1)
medications.head(2)
# Out:
#                       START                      STOP  \
# 0 2010-05-05 00:26:23+00:00 2011-04-30 00:26:23+00:00
# 1 2011-04-30 00:26:23+00:00 2012-04-24 00:26:23+00:00
#
#                                 PATIENT                                 PAYER  \
# 0  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#                               ENCOUNTER    CODE  \
# 0  1e0d6b0e-1711-4a25-99f9-b1c700c9b260  389221
# 1  6aa37300-d1b4-48e7-a2f8-5e0f70f48f38  389221
#
#                        DESCRIPTION  BASE_COST  PAYER_COVERAGE  DISPENSES  \
# 0  Etonogestrel 68 MG Drug Implant     677.08             0.0         12
# 1  Etonogestrel 68 MG Drug Implant     624.09             0.0         12
#
#    TOTALCOST  REASONCODE REASONDESCRIPTION stop-start
# 0    8124.96         NaN               NaN   360 days
# 1    7489.08         NaN               NaN   360 days

# %%
medications.head(20)
# Out:
#                        START                      STOP  \
# 0  2010-05-05 00:26:23+00:00 2011-04-30 00:26:23+00:00
# 1  2011-04-30 00:26:23+00:00 2012-04-24 00:26:23+00:00
# 2  2012-04-24 00:26:23+00:00 2013-04-19 00:26:23+00:00
# 3  2011-05-13 12:58:08+00:00 2011-05-27 12:58:08+00:00
# 4  2011-12-08 15:02:18+00:00 2011-12-22 15:02:18+00:00
# 5  2012-01-01 03:04:34+00:00 2012-01-08 03:04:34+00:00
# 6  2016-12-29 17:45:28+00:00 2017-01-05 17:45:28+00:00
# 7  2014-04-23 00:26:23+00:00 2015-04-18 00:26:23+00:00
# 8  2019-03-20 15:02:18+00:00 2019-04-10 15:02:18+00:00
# 9  2017-04-07 00:26:23+00:00 2018-04-02 00:26:23+00:00
# 10 2018-04-02 00:26:23+00:00 2019-03-28 00:26:23+00:00
# 11 2020-03-22 00:26:23+00:00                       NaT
# 12 2017-01-22 12:58:08+00:00 2017-02-12 12:58:08+00:00
# 13 2019-04-23 12:58:08+00:00 2019-05-07 12:58:08+00:00
# 14 2018-05-24 03:08:42+00:00 2018-06-21 03:08:42+00:00
# 15 2017-10-31 06:21:56+00:00 2017-11-14 06:21:56+00:00
# 16 2017-12-09 06:21:56+00:00 2018-12-04 06:21:56+00:00
# 17 2018-12-04 06:21:56+00:00 2019-11-29 06:21:56+00:00
# 18 2019-12-05 06:21:56+00:00 2019-12-12 06:21:56+00:00
# 19 2018-11-20 03:08:42+00:00 2018-12-04 03:08:42+00:00
#
#                                  PATIENT  \
# 16  d3cd48f5-ef49-416f-aab6-87f519830980   749762
# 17  d56e4657-0873-4b95-8b39-bdddd446c676   748879
# 18  52825d9e-3116-44cd-813d-ce1178f4b401   313782
# 19  2ddeea4b-cd90-4294-9519-ada1e1bd4d59   198405
#
#                                           DESCRIPTION  BASE_COST  \
# 0                     Etonogestrel 68 MG Drug Implant     677.08
# 1                     Etonogestrel 68 MG Drug Implant     624.09
# 2                                     Yaz 28 Day Pack      43.32
# 3                    Acetaminophen 325 MG Oral Tablet       8.14
# 4   Amoxicillin 250 MG / Clavulanate 125 MG Oral T...      11.91
# 5                    Acetaminophen 325 MG Oral Tablet       6.52
# 6                    Acetaminophen 325 MG Oral Tablet       6.41
# 7                     Etonogestrel 68 MG Drug Implant     624.08
# 8   Amoxicillin 250 MG / Clavulanate 125 MG Oral T...      29.89
# 9   168 HR Ethinyl Estradiol 0.00146 MG/HR / norel...      39.20
# 10                                Natazia 28 Day Pack      38.96
# 11  1 ML medroxyPROGESTERone acetate 150 MG/ML Inj...      69.75
# 12                 Naproxen sodium 220 MG Oral Tablet       5.73
# 13                   Acetaminophen 325 MG Oral Tablet       6.70
# 14               Acetaminophen 160 MG Chewable Tablet       5.73
# 15                   Acetaminophen 325 MG Oral Tablet       7.01
# 16                             Seasonique 91 Day Pack      34.36
# 17                         Levora 0.15/30 28 Day Pack      46.50
# 18                   Acetaminophen 325 MG Oral Tablet       7.87
# 19                       Ibuprofen 100 MG Oral Tablet      15.80
#
#     PAYER_COVERAGE  DISPENSES  TOTALCOST   REASONCODE  \
# 0              0.0         12    8124.96          NaN
# 1              0.0         12    7489.08          NaN
# 2              0.0         12     519.84          NaN
# 3              0.0          1       8.14   10509002.0
# 4              0.0          1      11.91  444814009.0
# 5              0.0          1       6.52   10509002.0
# 6              0.0          1       6.41   10509002.0
# 7              0.0         12    7488.96          NaN
# 8              0.0          1      29.89  444814009.0
# 9              0.0         12     470.40          NaN
# 10             0.0         12     467.52          NaN
# 11             0.0          1      69.75          NaN
# 12             0.0          1       5.73          NaN
# 13             0.0          1       6.70   10509002.0
# 14             0.0          1       5.73          NaN
# 15             0.0          1       7.01   10509002.0
# 16             0.0         12     412.32          NaN
# 17             0.0         12     558.00          NaN
# 18             0.0          1       7.87   10509002.0
# 19             0.0          1      15.80          NaN
#
#               REASONDESCRIPTION stop-start
# 0                           NaN   360 days
# 1                           NaN   360 days
# 2                           NaN   360 days
# 3   Acute bronchitis (disorder)    14 days
# 4    Viral sinusitis (disorder)    14 days
# 5   Acute bronchitis (disorder)     7 days
# 6   Acute bronchitis (disorder)     7 days
# 7                           NaN   360 days
# 8    Viral sinusitis (disorder)    21 days
# 9                           NaN   360 days
# 10                          NaN   360 days
# 11                          NaN        NaT
# 12                          NaN    21 days
# 13  Acute bronchitis (disorder)    14 days
# 14                          NaN    28 days
# 15  Acute bronchitis (disorder)    14 days
# 16                          NaN   360 days
# 17                          NaN   360 days
# 18  Acute bronchitis (disorder)     7 days
# 19                          NaN    14 days

# %%
medications.dtypes

# %%
import dateutil.parser

# %%
# d = dateutil.parser.parse('2008-09-26T01:51:42.000Z')
# print(d.strftime('%m/%d/%Y'))  #==> '09/26/2008'
